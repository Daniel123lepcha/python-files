# %%
import time

def intro():
    print("You wake up in a dimly lit room. It feels cold and eerie.")
    print("The room has a single door and a small window covered in grime.")
    print("You need to find a way to escape. Hurry!")
    print()

def room():
    print("You are in the room.")
    print("What do you want to do?")
    print("1. Examine the door")
    print("2. Look out the window")
    print("3. Check the surroundings")
    print("4. Quit the game")
    print()

def door():
    print("You approach the door.")
    print("It's old and creaky. The doorknob feels cold to the touch.")
    print("What do you want to do?")
    print("1. Try to open the door")
    print("2. Go back to the room")
    print()

def window():
    print("You go towards the window.")
    print("It's covered in dirt and grime, making it difficult to see outside.")
    print("What do you want to do?")
    print("1. Clean the window")
    print("2. Go back to the room")
    print()

def surroundings():
    print("You look around the room.")
    print("There's an old wooden table in the corner and a dusty rug on the floor.")
    print("What do you want to do?")
    print("1. Examine the table")
    print("2. Lift the rug")
    print("3. Go back to the room")
    print()

def table():
    print("You inspect the table.")
    print("There's a small key on the table.")
    print("What do you want to do?")
    print("1. Take the key")
    print("2. Go back to the surroundings")
    print()

def rug():
    print("You lift the rug and find a trapdoor underneath.")
    print("It seems to be locked.")
    print("What do you want to do?")
    print("1. Try using the key")
    print("2. Go back to the surroundings")
    print()

def escape():
    print("Congratulations! You found a way to escape!")
    print("You made it out alive... for now.")
    print("Thank you for playing!")
    print()

def game():
    intro()
    while True:
        room()
        choice = input("Enter your choice: ")
        print()
        if choice == "1":
            door_choice()
        elif choice == "2":
            window_choice()
        elif choice == "3":
            surroundings_choice()
        elif choice == "4":
            print("Quitting the game...")
            time.sleep(2)
            print("Game over!")
            break
        else:
            print("Invalid choice. Try again.")
            print()

def door_choice():
    door()
    choice = input("Enter your choice: ")
    print()
    if choice == "1":
        print("You try to open the door, but it's locked.")
        print("You need to find a key.")
        print()
    elif choice == "2":
        game()
    else:
        print("Invalid choice. Try again.")
        print()

def window_choice():
    window()
    choice = input("Enter your choice: ")
    print()
    if choice == "1":
        print("You try to clean the window, but it's too dirty to see anything")

# %%
game()
# Out:
# You wake up in a dimly lit room. It feels cold and eerie.
# The room has a single door and a small window covered in grime.
# You need to find a way to escape. Hurry!
#
# You are in the room.
# What do you want to do?
# 1. Examine the door
# 2. Look out the window
# 3. Check the surroundings
# 4. Quit the game
#
# Enter your choice: 1
#
# You approach the door.
# It's old and creaky. The doorknob feels cold to the touch.
# What do you want to do?
# 1. Try to open the door
# 2. Go back to the room
#
# Enter your choice: 2
#
# You wake up in a dimly lit room. It feels cold and eerie.
# The room has a single door and a small window covered in grime.
# You need to find a way to escape. Hurry!
#
# You are in the room.
# What do you want to do?
# 1. Examine the door
# 2. Look out the window
# 3. Check the surroundings
# 4. Quit the game
#
# Enter your choice: 2
#
# You go towards the window.
# It's covered in dirt and grime, making it difficult to see outside.
# What do you want to do?
# ...
